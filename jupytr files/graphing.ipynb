# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('iitm1623.csv')
df.drop(columns=df.columns[0], axis=1,  inplace=True)
df.drop_duplicates(keep='last', inplace=True)
df.convert_dtypes()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131 entries, 0 to 130
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       131 non-null    int64
#  1   institute  131 non-null    object
#  2   program    131 non-null    object
#  3   duration   131 non-null    object
#  4   degree     131 non-null    object
#  5   category   131 non-null    object
#  6   pool       131 non-null    object
#  7   opening    131 non-null    int64
#  8   closing    131 non-null    int64
# dtypes: int64(3), object(6)
# memory usage: 10.2+ KB

# %%
sigh = df[df['year']==2021]
sigh
# Out:
#      year   institute                                   program duration  \
# 89   2021  IIT-Madras                     Aerospace Engineering  4 Years
# 90   2021  IIT-Madras                     Aerospace Engineering  5 Years
# 91   2021  IIT-Madras                    Biological Engineering  5 Years
# 92   2021  IIT-Madras                       Biological Sciences  5 Years
# 93   2021  IIT-Madras                      Chemical Engineering  4 Years
# 94   2021  IIT-Madras                         Civil Engineering  4 Years
# 95   2021  IIT-Madras          Computer Science and Engineering  4 Years
# 96   2021  IIT-Madras                    Electrical Engineering  4 Years
# 97   2021  IIT-Madras                        Engineering Design  5 Years
# 98   2021  IIT-Madras                       Engineering Physics  4 Years
# 99   2021  IIT-Madras                    Mechanical Engineering  4 Years
# 100  2021  IIT-Madras   Metallurgical and Materials Engineering  4 Years
# ...

# %%
years5 = ['Aerospace Engineering','Biological Engineering', 'Biological Sciences' , 'Physics','Engineering Design']
y5 = ['Aerospace Engineering Dual','Biological Engineering', 'Biological Sciences' , 'Physics','Engineering Design']
years4 = ['Aerospace Engineering', 'Chemical Engineering','Civil Engineering', 'Computer Science and Engineering','Electrical Engineering', 'Engineering Physics','Mechanical Engineering', 'Metallurgical and Materials Engineering','Naval Architecture and Ocean Engineering',]
programs4 = np.array(years4)
programs5 = np.array(years5)
p5 = np.array(y5)

# %%
dual = df[df['duration']=='5 Years']
btech = df[df['duration']=='4 Years']

# %%
for i in range(9): 
    streamdf = btech[btech['program']==years4[i]]
    
    plt.figure(figsize=(15,7))
    plt.grid()
    plt.plot(streamdf['year'],streamdf['opening'],linewidth=3.5)
    plt.plot(streamdf['year'],streamdf['closing'],linewidth=3.5)
    
    
    for xy in zip(streamdf['year'],streamdf['opening']):
        plt.annotate('(%d, %d)' % xy, xy=xy)
    for xy in zip(streamdf['year'],streamdf['closing']):
        plt.annotate('(%d, %d)' % xy, xy=xy )
    
    plt.title(programs4[i])
    plt.show()

# %%
for i in range(5): 
    streamdf = dual[dual['program']==years5[i]]
    
    plt.figure(figsize=(15,7))
    plt.grid()
    plt.plot(streamdf['year'],streamdf['opening'],linewidth=3.5)
    plt.plot(streamdf['year'],streamdf['closing'],linewidth=3.5)
    
    
    for xy in zip(streamdf['year'],streamdf['opening']):
        plt.annotate('(%d, %d)' % xy, xy=xy)
    for xy in zip(streamdf['year'],streamdf['closing']):
        plt.annotate('(%d, %d)' % xy, xy=xy )
    
    plt.title(p5[i])
    plt.show()
